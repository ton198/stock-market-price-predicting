# %% [markdown]
# Data Generation:
#
# The average directional accuracy of the previous model is 0.67. The model has a large bias towards predicting 1, which means it is very strong at predicting the upward movement, however, it is very weak at predicting the downward movement, but we can use the confidence to interpret. The F1 score of the model for up is 0.75, down is 0.53(nearly random). But good news is it usually have a low confidence when it predicts down. it has around 409/1443 confident predictions(0.99 confidence), and the accuracy is 0.99. For other confidence levels(around 0.5-0.7), the accuracy is around 0.56, which is nearly random.
#
# Thus, we want to generate random samples following the same distribution.
# The overall accuracy should be around 0.67.
